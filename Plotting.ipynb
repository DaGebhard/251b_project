# %%
import matplotlib.pyplot as plt
import pandas as pd
import os


path = ""
df = pd.read_csv(os.path.join(path, "monitor.csv"), names=["mean reward per epoch", "mean epoch length", "time"], skiprows=[0, 1])
df["mean reward per epoch"].plot()
plt.xlabel("timesteps x 1000")
plt.ylabel("mean reward per epoch")
plt.savefig(os.path.join(path, "rewards.png"))
plt.show()
plt.close()
df["mean epoch length"].plot()
plt.xlabel("timesteps x 1000")
plt.ylabel("mean epoch length")
plt.savefig(os.path.join(path, "epsiode length.png"))
plt.show()
plt.close()
